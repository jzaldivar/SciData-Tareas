# %% [markdown]
# # La agencia de viajes
#
# Supongamos que somos un agente de Airbnb localizado en CDMX, y tenemos que atender peticiones de varios clientes. Tenemos un archivo llamado airbnb_cdmx.csv donde tenemos información de todos los alojamientos de Airbnb en CDMX

# %% [markdown]
# En concreto el dataset tiene las siguientes variables:
#
# * id: el identificador de la propiedad
# * host_id: el identificador del dueño de la propiedad
# * neighborhood_cleansed: alcaldía en CDMX
# * property_type: tipo de propiedad
# * room_type: tipo de habitación
# * accommodates: El numero de personas que se pueden alojar en la propiedad
# * price: precio (en pesos mexicanos)
# * minimum_nights, maximum_nights: mínimo y máximo de noches
# * bedrooms: El número de habitaciones
# * beds: número de camas
# * cancellation_policy: política de cancelación
# * number_of_reviews: El numero de opiniones
# * review_scores_accuracy: Puntuacion media del apartamento

# %%
import numpy as np
import pandas as pd

# %%
airbnb = pd.read_csv("airbnb_cdmx.csv")
airbnb.head()
# Out:
#        id  host_id neighbourhood_cleansed property_type        room_type  \
# 0   35797   153786  Cuajimalpa de Morelos         Villa  Entire home/apt
# 1   56074   265650             Cuauhtemoc   Condominium  Entire home/apt
# 2   61792   299558             Cuauhtemoc         House     Private room
# 3   70644   212109               Coyoacan     Apartment  Entire home/apt
# 4  107078   540705         Miguel Hidalgo          Loft  Entire home/apt
#
#    accommodates  price  minimum_nights  maximum_nights  bedrooms  beds  \
# 0             2   4500               1               7       1.0   1.0
# 1             3    843               4             150       1.0   2.0
# 2             2   1359               2              21       1.0   1.0
# 3             2   1245               6             180       1.0   1.0
# 4             2   4868               4             365       1.0   1.0
#
#            cancellation_policy  number_of_reviews  review_scores_accuracy
# 0                     flexible                  0                     NaN
# 1                     moderate                 60                    10.0
# 2                     moderate                 52                    10.0
# 3                     moderate                102                    10.0
# 4  strict_14_with_grace_period                 10                    10.0

# %% [markdown]
# ## Alicia y su familia
#
# Alicia va a ir a CDMX durante una semana con su marido y sus 2 hijos. Están buscando un apartamento con habitaciones separadas para los padres y los hijos. No les importa donde alojarse o el precio, simplemente quieren tener una experiencia agradable. Esto significa que solo aceptan lugares con más de 10 críticas con una puntuación mayor de 4. Cuando seleccionemos habitaciones para Alicia, tenemos que asegurarnos de ordenar las habitaciones de mejor a peor puntuación. Para aquellas habitaciones que tienen la misma puntuación, debemos mostrar antes aquellas con más críticas. Debemos a lo más la tercera parte del total de posibilidades.

# %%
""" 
Filtrar:
 noches_estancia = 6
 habitaciones >= 2
 num_criticas > 10
 puntuacion > 4
Ordenar descendente por puntuación
Misma puntuación, ordenar por num_críticas descendente
Mostrar solo 1/3 de los resultados
"""

# Noches:
# Se quiere quedar exactamente 6 noches.
# Las propiedades que le sirven son aquellas que:
# - no pidan un mínimo mayor a 6 y
# - no tengan un máximo menor a 6.
f1 = airbnb["maximum_nights"] >= 6
f2 = airbnb["minimum_nights"] <= 6
# Habitaciones separadas para papás e hijos
f3 = airbnb["bedrooms"] >= 2
# Mínimo 4 personas
f4 = airbnb["accommodates"] >= 4
# Mínimo 10 críticas
f5 = airbnb["number_of_reviews"] > 10
# Puntuación mínima de 4
f6 = airbnb["review_scores_accuracy"] > 4
# Combinar filtros
opciones = airbnb[f1 & f2 & f3 & f4 & f5 & f6]
opciones
# Out:
#              id    host_id neighbourhood_cleansed property_type  \
# 6        165772     790208         Miguel Hidalgo         House
# 9        187030     899360             Cuauhtemoc     Apartment
# 12       198778     970609             Cuauhtemoc     Apartment
# 15       246057    1288063             Cuauhtemoc     Apartment
# 19       256555     790208         Miguel Hidalgo         House
# ...         ...        ...                    ...           ...
# 19714  42202314  132484396          Benito Juarez     Apartment
# 19741  42224748  335393886         Miguel Hidalgo   Condominium
# 19771  42249246  332120390          Benito Juarez     Apartment
# 19800  42272228  335393886         Miguel Hidalgo   Condominium
# 19908  42360548  136203553               Coyoacan     Apartment
#
#              room_type  accommodates  price  minimum_nights  maximum_nights  \
# 6      Entire home/apt            14   1245               2             365
# 9      Entire home/apt             6   1314               3             365
# 12     Entire home/apt             4   1087               2             365
# 15     Entire home/apt             5   1699               1              30
# 19     Entire home/apt            14   1245               2             365
# ...                ...           ...    ...             ...             ...
# 19714  Entire home/apt             5    725               2            1125
# 19741  Entire home/apt             4   2332               1              30
# 19771  Entire home/apt             5   1200               1            1125
# 19800  Entire home/apt             4   2255               1              30
# 19908  Entire home/apt             4    957               1            1125
#
#        bedrooms  beds          cancellation_policy  number_of_reviews  \
# 6           4.0  10.0  strict_14_with_grace_period                266
# 9           2.0   3.0                     moderate                 97
# 12          2.0   4.0  strict_14_with_grace_period                169
# 15          2.0   4.0                     flexible                247
# 19          4.0  10.0  strict_14_with_grace_period                264
# ...         ...   ...                          ...                ...
# 19714       2.0   3.0  strict_14_with_grace_period                 12
# 19741       2.0   2.0                     moderate                 21
# 19771       2.0   3.0                     flexible                 13
# 19800       2.0   2.0                     moderate                 15
# 19908       2.0   3.0                     moderate                 14
#
#        review_scores_accuracy
# 6                        10.0
# 9                        10.0
# 12                        9.0
# 15                       10.0
# 19                       10.0
# ...                       ...
# 19714                    10.0
# 19741                    10.0
# 19771                    10.0
# 19800                    10.0
# 19908                    10.0
#
# [2972 rows x 14 columns]

# %%
# Ordenar
opciones = opciones.sort_values(by=["review_scores_accuracy", "number_of_reviews"],
                     ascending=[False, False])

# %%
# Limitar solo a la tercera parte
num_opciones = opciones.shape[0] // 3
opciones = opciones.head(num_opciones)
opciones
# Out:
#              id    host_id neighbourhood_cleansed property_type  \
# 2800   14150131   10644799    Venustiano Carranza          Loft
# 6024   21052296  151657679              Iztacalco     Apartment
# 581     4801896   20440301             Cuauhtemoc     Apartment
# 2520   13398036   70937648             Cuauhtemoc     Apartment
# 137      997247    5479592             Cuauhtemoc     Apartment
# ...         ...        ...                    ...           ...
# 8739   25973891  100844511               Coyoacan     Apartment
# 9875   28409727   39346393         Miguel Hidalgo     Apartment
# 10751  30009282  202890617             Cuauhtemoc     Apartment
# 11278  30979411   82121841             Cuauhtemoc     Apartment
# 11921  31982929  239786492             Cuauhtemoc     Apartment
#
#              room_type  accommodates  price  minimum_nights  maximum_nights  \
# 2800   Entire home/apt             4    473               1            1125
# 6024   Entire home/apt             4    540               1            1125
# 581    Entire home/apt             4   1993               1             150
# 2520   Entire home/apt             4   1200               1            1125
# 137    Entire home/apt             4   1812               2            1000
# ...                ...           ...    ...             ...             ...
# 8739   Entire home/apt             4    900               2             180
# 9875   Entire home/apt             6   1449               1            1125
# 10751  Entire home/apt             5   1993               2              30
# 11278  Entire home/apt             7   1948               2            1125
# 11921  Entire home/apt             6   1699               2            1125
#
#        bedrooms  beds          cancellation_policy  number_of_reviews  \
# 2800        2.0   3.0                     flexible                506
# 6024        2.0   2.0                     flexible                424
# 581         2.0   2.0                     flexible                365
# 2520        2.0   2.0                     moderate                342
# 137         2.0   2.0  strict_14_with_grace_period                333
# ...         ...   ...                          ...                ...
# 8739        2.0   3.0                     flexible                 52
# 9875        2.0   3.0  strict_14_with_grace_period                 52
# 10751       3.0   3.0                     moderate                 52
# 11278       2.0   4.0                     moderate                 52
# 11921       2.0   3.0                     moderate                 52
#
#        review_scores_accuracy
# 2800                     10.0
# 6024                     10.0
# 581                      10.0
# 2520                     10.0
# 137                      10.0
# ...                       ...
# 8739                     10.0
# 9875                     10.0
# 10751                    10.0
# 11278                    10.0
# 11921                    10.0
#
# [990 rows x 14 columns]

# %% [markdown]
# ## Roberto contra su hermana
#
# Roberto es un casero que tiene una casa en Airbnb. De vez en cuando nos llama preguntando sobre cuales son las críticas de su alojamiento. Hoy está particularmente molesto, ya que su hermana Valentina ha puesto una casa en Airbnb y Roberto quiere asegurarse de que su casa tiene más críticas que las de Valentina. Tenemos que crear un dataframe con las propiedades de ambos. Las id de las casas de Roberto y Valentina son 43856289 y 107078 respectivamente.

# %%
# Crear filtros
casa_roberto = airbnb["id"] == 43856289
casa_valentina = airbnb["id"] == 107078
# Aplicar filtros
airbnb[casa_roberto | casa_valentina]
# Out:
#              id   host_id neighbourhood_cleansed property_type  \
# 4        107078    540705         Miguel Hidalgo          Loft
# 21819  43856289  63979434             Cuauhtemoc         House
#
#              room_type  accommodates  price  minimum_nights  maximum_nights  \
# 4      Entire home/apt             2   4868               4             365
# 21819     Private room             4    996               1              15
#
#        bedrooms  beds          cancellation_policy  number_of_reviews  \
# 4           1.0   1.0  strict_14_with_grace_period                 10
# 21819       1.0   3.0                     flexible                  0
#
#        review_scores_accuracy
# 4                        10.0
# 21819                     NaN

# %% [markdown]
# ## Diana "la mochilera"
#
# Diana va a CDMX a pasar 3 noches y quiere conocer a gente nueva. Tiene un presupuesto de 1,250 pesos mexicanos para su alojamiento. Debemos buscarle las 10 propiedades más baratas, dandole preferencia a aquellas que sean habitaciones compartidas, y para aquellas viviendas compartidas debemos elegir aquellas con mejor puntuación.

# %%
# Tipos de habitaciones
airbnb["room_type"].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
# Datos
presupuesto = 1250
noches = 3

# Filtros
# Presupuesto
fp = airbnb["price"] <= presupuesto/noches
# Noches
fn = (airbnb["minimum_nights"] <= 3) & (airbnb["maximum_nights"] >= 3)
# Cuartos compartidos
fc = airbnb["room_type"] == "Shared room"

# %%
# Aplicar filtros
diana = airbnb[fp & fn & fc]

# Ordenar
# 1. Precio
# 2. Que sea habitación compartida
# 3. Mejor puntuación
diana = diana.sort_values(by=["price", "review_scores_accuracy"], ascending=[True, False])
# Sólo las mejores 10
diana = diana.head(10)
diana
# Out:
#              id    host_id neighbourhood_cleansed property_type    room_type  \
# 7728   23877762  179398369                Tlalpan          Loft  Shared room
# 19417  41917043  321717003             Iztapalapa   Condominium  Shared room
# 12068  32197684  229856606                Tlalpan         House  Shared room
# 11666  31588864  124718595                Tlahuac     Apartment  Shared room
# 9676   28008247  211537057                Tlalpan     Apartment  Shared room
# 6345   21596500    2269083         Miguel Hidalgo     Apartment  Shared room
# 7377   23255186   94336357          Benito Juarez     Apartment  Shared room
# 12186  32381892  238972976             Cuauhtemoc        Hostel  Shared room
# 16977  39228937  224496196             Cuauhtemoc     Apartment  Shared room
# 17643  39997048  305453762             Cuauhtemoc        Hostel  Shared room
#
#        accommodates  price  minimum_nights  maximum_nights  bedrooms  beds  \
# 7728              1    159               1            1125       1.0   1.0
# 19417             3    179               1             365       1.0   0.0
# 12068             1    180               3            1125       1.0   1.0
# 11666             1    180               1            1125       1.0   1.0
# 9676              1    180               2              31       1.0   1.0
# 6345              1    181               3            1125       1.0   1.0
# 7377              1    181               2              20       1.0   2.0
# 12186            16    181               1            1125       1.0  18.0
# 16977             1    181               1              90       1.0   1.0
# 17643             8    181               1             365       1.0   8.0
#
#                cancellation_policy  number_of_reviews  review_scores_accuracy
# 7728                      flexible                  0                     NaN
# 19417                     flexible                  0                     NaN
# 12068                     moderate                  1                    10.0
# 11666                     flexible                  3                     9.0
# 9676                      moderate                  0                     NaN
# 6345                      flexible                  2                    10.0
# 7377                      flexible                  3                    10.0
# 12186  strict_14_with_grace_period                  9                    10.0
# 16977  strict_14_with_grace_period                  9                    10.0
# 17643                     moderate                  8                    10.0

# %%
""" 
Al mencionar que se quiere ordenar dándole preferencia a aquellas que sean compartidas,
se implica que también pueden ser habitaciones no compartidas, entonces, hay que desechar
uno de los filtros para permitir habitaciones no compartidas.
"""
diana = airbnb[fp & fn]

# Agregamos columna auxiliar para ordenar por habitación compartida:
diana["shared"] = diana["room_type"] == "Shared room"
# Y, ahora sí, ordenar:
diana = diana.sort_values(by=["price", "shared", "review_scores_accuracy"], ascending=[True, False, False])
diana = diana.head(10)
diana
# Out:
# C:\Users\JorgeZaldivar\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#              id    host_id neighbourhood_cleansed   property_type  \
# 6113   21212741   48001186         Miguel Hidalgo       Apartment
# 6138   21266125   30026600         Miguel Hidalgo            Loft
# 5653   20435525   64371831             Cuauhtemoc       Apartment
# 5602   20277868  134853067               Coyoacan          Hostel
# 4738   18570933   76376610         Miguel Hidalgo            Loft
# 20122  42534951  113550322             Cuauhtemoc           Hotel
# 20123  42534965  307295793             Cuauhtemoc  Boutique hotel
# 20124  42534993  307292215             Cuauhtemoc           Hotel
# 20187  42583200  305545617             Cuauhtemoc           Hotel
# 17593  39948133  126456380               Coyoacan           House
#
#              room_type  accommodates  price  minimum_nights  maximum_nights  \
# 6113      Private room             2      0               1              30
# 6138   Entire home/apt             3      0               3             400
# 5653   Entire home/apt             7      0               1              30
# 5602      Private room             2      0               1            1125
# 4738   Entire home/apt             2      0               1            1125
# 20122       Hotel room             2      0               1             365
# 20123       Hotel room             2      0               1             365
# 20124       Hotel room             2      0               1             365
# 20187       Hotel room             2      0               1             365
# 17593     Private room             4     23               1            1125
#
#        bedrooms  beds          cancellation_policy  number_of_reviews  \
# 6113        1.0   1.0  strict_14_with_grace_period                 29
# 6138        0.0   2.0                     flexible                  1
# 5653        3.0   4.0  strict_14_with_grace_period                105
# 5602        1.0   1.0                     moderate                  1
# 4738        1.0   1.0                     flexible                  0
# 20122       NaN   NaN                     moderate                  0
# 20123       NaN   NaN                     moderate                  0
# 20124       NaN   NaN                     moderate                  0
# 20187       NaN   NaN                     moderate                  0
# 17593       1.0   2.0                     moderate                  5
#
#        review_scores_accuracy  shared
# 6113                     10.0   False
# 6138                     10.0   False
# 5653                      9.0   False
# 5602                      6.0   False
# 4738                      NaN   False
# 20122                     NaN   False
# 20123                     NaN   False
# 20124                     NaN   False
# 20187                     NaN   False
# 17593                    10.0   False

# %%
# Obtuvimos propiedades con precio 0,
# algo parece estar mal con los registros.

# Vamos a eliminar esos registros modificando el filtro de precios.
fp = (airbnb["price"] <= presupuesto/noches) & (airbnb["price"] > 0)

# %%
# Y repetimos todo lo anterior
# Filtrar
diana = airbnb[fp & fn].copy()  # <-- Y de una vez nos quitamos el _warning_ de arriba con el copy()
# Agregar columna
diana["shared"] = diana["room_type"] == "Shared room"
# Y, ahora sí, ordenar:
diana = diana.sort_values(by=["price", "shared", "review_scores_accuracy"], ascending=[True, False, False])
diana = diana.head(10)
diana
# Out:
#              id    host_id neighbourhood_cleansed property_type  \
# 17593  39948133  126456380               Coyoacan         House
# 19399  41909745   78891216          Benito Juarez         House
# 5713   20557042   64225887          Benito Juarez     Apartment
# 18657  41113140  320683349               Coyoacan          Loft
# 19701  42193723  218080886          Benito Juarez   Guest suite
# 5675   20476924  136277876             Cuauhtemoc         House
# 19147  41642951  160469905          Benito Juarez     Apartment
# 9428   27552465  163628660          Benito Juarez     Apartment
# 7728   23877762  179398369                Tlalpan          Loft
# 19674  42151081  257679722               Coyoacan     Apartment
#
#              room_type  accommodates  price  minimum_nights  maximum_nights  \
# 17593     Private room             4     23               1            1125
# 19399     Private room             1     23               1              20
# 5713      Private room             2     45               1               5
# 18657  Entire home/apt             2     45               2            1125
# 19701  Entire home/apt             2     45               2            1125
# 5675      Private room             2     45               1            1125
# 19147  Entire home/apt             4     46               3            1125
# 9428      Private room             1     91               1               7
# 7728       Shared room             1    159               1            1125
# 19674     Private room             2    159               1            1125
#
#        bedrooms  beds cancellation_policy  number_of_reviews  \
# 17593       1.0   2.0            moderate                  5
# 19399       1.0   1.0            moderate                  0
# 5713        1.0   1.0            flexible                  8
# 18657       0.0   2.0            moderate                  7
# 19701       0.0   1.0            flexible                  2
# 5675        1.0   1.0            flexible                  0
# 19147       2.0   2.0            flexible                  1
# 9428        1.0   1.0            flexible                  5
# 7728        1.0   1.0            flexible                  0
# 19674       1.0   1.0            flexible                  6
#
#        review_scores_accuracy  shared
# 17593                    10.0   False
# 19399                     NaN   False
# 5713                     10.0   False
# 18657                    10.0   False
# 19701                    10.0   False
# 5675                      NaN   False
# 19147                    10.0   False
# 9428                     10.0   False
# 7728                      NaN    True
# 19674                    10.0   False

# %%
# Vamos a intentar hacerlo ahora sin agregar la columna extra al DataFrame
# (haciendo los cálculos implícitos)

# Filtrar
diana = airbnb[fp & fn]

# %%
# Construir un DataFrame auxiliar con las columnas de ordenación
df_p = diana["price"]
df_r = diana["room_type"].where(diana["room_type"]=="Shared room", other="ZZZ")
df_s = diana["review_scores_accuracy"]
orden = pd.concat([df_p, df_r, df_s], axis=1)
orden.columns = ["price", "room", "score"]
# Ordenar el DataFrame auxiliar
orden = orden.sort_values(by=["price", "room", "score"], ascending=[True, True, False])
# Usar los índices del DataFrame auxiliar para ordenar
diana = diana.loc[orden.index]
# Solo las primeras 10 opciones
diana = diana.head(10)
diana
# Out:
#              id    host_id neighbourhood_cleansed property_type  \
# 17593  39948133  126456380               Coyoacan         House
# 19399  41909745   78891216          Benito Juarez         House
# 5713   20557042   64225887          Benito Juarez     Apartment
# 18657  41113140  320683349               Coyoacan          Loft
# 19701  42193723  218080886          Benito Juarez   Guest suite
# 5675   20476924  136277876             Cuauhtemoc         House
# 19147  41642951  160469905          Benito Juarez     Apartment
# 9428   27552465  163628660          Benito Juarez     Apartment
# 7728   23877762  179398369                Tlalpan          Loft
# 19674  42151081  257679722               Coyoacan     Apartment
#
#              room_type  accommodates  price  minimum_nights  maximum_nights  \
# 17593     Private room             4     23               1            1125
# 19399     Private room             1     23               1              20
# 5713      Private room             2     45               1               5
# 18657  Entire home/apt             2     45               2            1125
# 19701  Entire home/apt             2     45               2            1125
# 5675      Private room             2     45               1            1125
# 19147  Entire home/apt             4     46               3            1125
# 9428      Private room             1     91               1               7
# 7728       Shared room             1    159               1            1125
# 19674     Private room             2    159               1            1125
#
#        bedrooms  beds cancellation_policy  number_of_reviews  \
# 17593       1.0   2.0            moderate                  5
# 19399       1.0   1.0            moderate                  0
# 5713        1.0   1.0            flexible                  8
# 18657       0.0   2.0            moderate                  7
# 19701       0.0   1.0            flexible                  2
# 5675        1.0   1.0            flexible                  0
# 19147       2.0   2.0            flexible                  1
# 9428        1.0   1.0            flexible                  5
# 7728        1.0   1.0            flexible                  0
# 19674       1.0   1.0            flexible                  6
#
#        review_scores_accuracy
# 17593                    10.0
# 19399                     NaN
# 5713                     10.0
# 18657                    10.0
# 19701                    10.0
# 5675                      NaN
# 19147                    10.0
# 9428                     10.0
# 7728                      NaN
# 19674                    10.0

# %% [markdown]
# Sí se pudo ordenar sin agregar la columna auxiliar. Sin embargo, el proceso de crear el DataFrame auxiliar es mucho más complejo que crear la columna auxiliar. Si se hubiera hecho como se pretendía (haciendo los cálculos implícitos), el código hubiera quedado aún más complicado.
